# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Path = /content/gdrive/MyDrive/AI_Project_data/data.csv

import pandas as pd
dataset = pd.read_csv("/content/gdrive/MyDrive/AI_Project_data/data.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0                                           Sentence Sentiment
# 0           0  The GeoSolutions technology will leverage Bene...  positive
# 1           1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2           2  For the last quarter of 2010 , Componenta 's n...  positive
# 3           3  According to the Finnish-Russian Chamber of Co...   neutral
# 4           4  The Swedish buyout firm has sold its remaining...   neutral

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset.head()
# Out:
#    Unnamed: 0                                           Sentence Sentiment
# 0           0  The GeoSolutions technology will leverage Bene...  positive
# 1           1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2           2  For the last quarter of 2010 , Componenta 's n...  positive
# 3           3  According to the Finnish-Russian Chamber of Co...   neutral
# 4           4  The Swedish buyout firm has sold its remaining...   neutral

# %%
dataset.shape
# Out:
# (5842, 3)

# %%
dataset['Sentiment'].unique()
# Out:
# array(['positive', 'negative', 'neutral'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['Sentiment'] = le.fit_transform(dataset['Sentiment'])

# %%
dataset.head()
# Out:
#    Unnamed: 0                                           Sentence  Sentiment
# 0           0  The GeoSolutions technology will leverage Bene...          2
# 1           1  $ESI on lows, down $1.50 to $2.50 BK a real po...          0
# 2           2  For the last quarter of 2010 , Componenta 's n...          2
# 3           3  According to the Finnish-Russian Chamber of Co...          1
# 4           4  The Swedish buyout firm has sold its remaining...          1

# %%
# train_data：待划分样本数据
# train_target：待划分样本数据的结果（标签）

train_data = dataset.drop('Sentiment', axis=1)
train_target = dataset['Sentiment']

print("train_data shape: {} \ntrain_target shape: {}".format(train_data.shape, train_target.shape))
# Out:
# train_data shape: (5842, 2)
# train_target shape: (5842,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_data, train_target, test_size=0.33, random_state=42)

print("X_train shape: {} \ny_train shape: {}".format(X_train.shape, y_train.shape))
print("X_test shape: {} \ny_test shape: {}".format(X_test.shape, y_test.shape))
# Out:
# X_train shape: (3914, 2)
# y_train shape: (3914,)
# X_test shape: (1928, 2)
# y_test shape: (1928,)

# %%
X_train
# Out:
#       Unnamed: 0                                           Sentence
# 3337        3337  National sponsors for The Big Read include Nat...
# 3666        3666  UPDATE: Barclays Expects Gain After Settling W...
# 1538        1538  They are also upset that some of the machinery...
# 211          211  A total 30 % of the order value was booked in ...
# 1340        1340  Rautakesko 's business operations in Norway an...
# ...          ...                                                ...
# 3772        3772  @BULLYA @pollux654321 My 50 $KORS 80 Calls are...
# 5191        5191  According to Sepp+ñnen , the new technology UM...
# 5226        5226   $CRUS Upgraded to a buy by Alpha Street Research
# 5390        5390  Favourable currency rates also contributed to ...
# 860          860  Tesco breaks its downward slide by cutting sal...
#
# [3914 rows x 2 columns]

# %%
y_train
# Out:
# 3337    1
# 3666    2
# 1538    1
# 211     1
# 1340    1
#        ..
# 3772    2
# 5191    2
# 5226    2
# 5390    2
# 860     2
# Name: Sentiment, Length: 3914, dtype: int64

# %%
X_test
# Out:
#       Unnamed: 0                                           Sentence
# 4584        4584  A few employees would remain at the Oulu plant...
# 177          177  Comparable net sales are expected to increase ...
# 167          167  Tesla is recalling 2,700 Model X cars: https:/...
# 5585        5585  Finnish software developer Done Solutions Oyj ...
# 2339        2339  Compagnie de Financement Foncier - Is to issue...
# ...          ...                                                ...
# 1534        1534  Finnish Vacon has signed significant deals wit...
# 1061        1061  Operating profit was EUR 1.6 mn in 2005 compar...
# 843          843  Britain's FTSE bounces back, Mondi and Barratt...
# 3148        3148  Pharmaceuticals - Netherlands This brand-new m...
# 4624        4624  Both Mr Walden and Mr Ignatius will be respons...
#
# [1928 rows x 2 columns]

# %%
y_test
# Out:
# 4584    1
# 177     2
# 167     0
# 5585    2
# 2339    1
#        ..
# 1534    2
# 1061    1
# 843     2
# 3148    1
# 4624    1
# Name: Sentiment, Length: 1928, dtype: int64

# %%
# pip install num2words
# Out:
# ...
#      |████████████████████████████████| 101 kB 5.1 MB/s
# ...

# %%
import numpy as np
import nltk
import string
import num2words 

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer


nltk.download('stopwords')
nltk.download('punkt')

def convert_lower_case(data):
    return np.char.lower(data)

def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) 
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    data = stemming(data)
    return data

# %%
dataset['Sentence'] = dataset['Sentence'].apply(lambda x : preprocess(x))

# %%
from collections import Counter
cnt=Counter()

for text in dataset['Sentence'].values:
    for word in text.split():
        cnt[word]+=1

# %%
cnt.most_common(45)
# Out:
# [('eur', 1286),
#  ('compani', 917),
#  ('mn', 729),
#  ('oper', 641),
#  ('sale', 609),
#  ('profit', 607),
#  ('finnish', 540),
#  ('year', 528),
#  ('share', 524),
#  ('said', 516),
#  ('net', 500),
#  ('million', 493),
#  ('2009', 358),
#  ('mln', 351),
#  ('2008', 350),
#  ('quarter', 348),
#  ('market', 344),
#  ('finland', 339),
#  ('period', 338),
#  ('group', 337),
#  ('2007', 306),
#  ('total', 304),
#  ('product', 295),
#  ('co', 294),
#  ('servic', 291),
#  ('new', 282),
#  ('http', 271),
#  ('busi', 271),
#  ('2010', 257),
#  ('euro', 257),
#  ('oyj', 250),
#  ('first', 245),
#  ('loss', 234),
#  ('increa', 226),
#  ('compar', 223),
#  ('also', 211),
#  ('report', 211),
#  ('today', 202),
#  ('2006', 198),
#  ('price', 192),
#  ('develop', 192),
#  ('includ', 182),
#  ('helsinki', 176),
#  ('financ', 172),
#  ('contract', 170)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(40)])
def remove_freqwords(text):
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

# %%
dataset['Sentence'] = dataset['Sentence'].apply(lambda x : remove_freqwords(x))

# %%
dataset.head()
# Out:
#    Unnamed: 0                                           Sentence  Sentiment
# 0           0  geosolut technolog leverag benefon gp solut pr...          2
# 1           1                      esi low 50 50 bk real possibl          0
# 2           2  last componenta doubl eur131m eur76m earlier m...          2
# 3           3  accord russian chamber commerc major construct...          1
# 4           4  swedish buyout firm sold remain 22 percent sta...          1

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

bag_of_words = CountVectorizer()
train_m_bow = bag_of_words.fit_transform(X_train['Sentence']).toarray()
test_m_bow = bag_of_words.transform(X_test['Sentence']).toarray()

# %%
train_m_bow.shape
# Out:
# (3914, 9129)

# %%
test_m_bow.shape
# Out:
# (1928, 9129)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score


nb_bow = MultinomialNB()
svm_bow = SVC()
dt_bow = DecisionTreeClassifier()
rf_bow = RandomForestClassifier()

clfs = {
    "Naive Bayes": nb_bow,
    "Decision Tree": dt_bow,
    "Random Forest": rf_bow,
    "SVM": svm_bow
}

def fit_model(clf,X_train,y_train,X_test, y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_pred, y_test)
    return accuracy

accuracy = []

for name,clf in clfs.items():
    curr_acc = fit_model(clf,train_m_bow,y_train,test_m_bow,y_test)
    accuracy.append(curr_acc)
    
# models_df = pd.DataFrame({"Models":clfs.keys(),"Accuracy Scores":accuracy}).sort_values('Accuracy Scores',ascending=False)
# models_df

# %%
models_df = pd.DataFrame({"Models":clfs.keys(),"Accuracy Scores":accuracy}).sort_values('Accuracy Scores',ascending=False)
models_df
# Out:
#           Models  Accuracy Scores
# 0    Naive Bayes         0.707988
# 3            SVM         0.683610
# 2  Random Forest         0.642635
# 1  Decision Tree         0.596473

# %%
models_re2 = pd.DataFrame({"Predict result":nb_bow.predict(test_m_bow),"Actual result":y_test})
models_re2
# Out:
#       Predict result  Actual result
# 4584               1              1
# 177                2              2
# 167                0              0
# 5585               2              2
# 2339               1              1
# ...              ...            ...
# 1534               2              2
# 1061               0              1
# 843                2              2
# 3148               1              1
# 4624               1              1
#
# [1928 rows x 2 columns]
